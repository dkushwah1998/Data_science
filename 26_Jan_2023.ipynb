# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\HP\Desktop\Data Sets\googleplaystore.csv")
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
df.shape
# Out:
# (10841, 13)

# %%
df1 = df.query("Rating >= 4.5")

# %%
df1.head(2)
# Out:
#                                                  App        Category  Rating  \
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
#
#   Reviews  Size     Installs  Type Price Content Rating        Genres  \
# 2   87510  8.7M   5,000,000+  Free     0       Everyone  Art & Design
# 3  215644   25M  50,000,000+  Free     0           Teen  Art & Design
#
#      Last Updated         Current Ver   Android Ver
# 2  August 1, 2018               1.2.4  4.0.3 and up
# 3    June 8, 2018  Varies with device    4.2 and up

# %%
df2 = df1.sort_values("Rating")
df2
# Out:
#                                                  App   Category  Rating  \
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology  LIFESTYLE     4.5
# 6534                       New York Mysteries (Full)       GAME     4.5
# 6543        Bangla Calendar 1425: (EN-BN-AR) Holiday  LIFESTYLE     4.5
# 6550                                    Bubble Bo-Bo     FAMILY     4.5
# 6551                                      Boom Beach     FAMILY     4.5
# ...                                              ...        ...     ...
# 9806                            Dr. ES PV Calculator      TOOLS     5.0
# 7533                                        Color CL  LIFESTYLE     5.0
# 7482                                      Tic Tac CK     FAMILY     5.0
# 7477                      USMLE Step 2 CK Flashcards     FAMILY     5.0
# 10472        Life Made WI-Fi Touchscreen Photo Frame        1.9    19.0
#
#        Reviews    Size     Installs  Type     Price Content Rating  \
# ...

# %%
df2.tail()
# Out:
#                                            App   Category  Rating Reviews  \
# 9806                      Dr. ES PV Calculator      TOOLS     5.0      19
# 7533                                  Color CL  LIFESTYLE     5.0       2
# 7482                                Tic Tac CK     FAMILY     5.0       3
# 7477                USMLE Step 2 CK Flashcards     FAMILY     5.0       1
# 10472  Life Made WI-Fi Touchscreen Photo Frame        1.9    19.0    3.0M
#
#          Size Installs  Type     Price Content Rating             Genres  \
# 9806      11M     500+  Free         0       Everyone              Tools
# 7533     1.3M     100+  Free         0       Everyone          Lifestyle
# 7482      13M      10+  Free         0       Everyone             Puzzle
# 7477      40M      10+  Paid    $19.99       Everyone          Education
# 10472  1,000+     Free     0  Everyone            NaN  February 11, 2018
#
#            Last Updated Current Ver   Android Ver
# ...

# %%
df2.query("Rating>5")
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
df.sample(15)
# Out:
#                                                     App             Category  \
# 971                      Viki: Asian TV Dramas & Movies        ENTERTAINMENT
# 4797                             Talking Tom & Ben News               FAMILY
# 2841                      Photo Collage - Layout Editor          PHOTOGRAPHY
# 5123                            Ag PhD Soybean Diseases  BOOKS_AND_REFERENCE
# 2479                            high cholesterol levels              MEDICAL
# 2870           InstaSize Photo Filters & Collage Editor          PHOTOGRAPHY
# 4190                                  H*nest Meditation            LIFESTYLE
# 2619                                            Timehop               SOCIAL
# 2944  Candy Camera - selfie, beauty camera, photo ed...          PHOTOGRAPHY
# 7439                         CJ Wilson's ZoomZoomnation         PRODUCTIVITY
# 7914                           Public Service CU Mobile              FINANCE
# ...

# %%
df.shape
# Out:
# (10841, 13)

# %%
df3 = df.dropna()
df3.shape
# Out:
# (9360, 13)

# %%
d = df3.groupby("Genres").mean("Rating")
d
# Out:
#                                          Rating
# Genres
# Action                                 4.285475
# Action;Action & Adventure              4.311765
# Adventure                              4.180822
# Adventure;Action & Adventure           4.423077
# Adventure;Brain Games                  4.600000
# ...                                         ...
# Video Players & Editors                4.063924
# Video Players & Editors;Creativity     4.100000
# Video Players & Editors;Music & Video  4.000000
# Weather                                4.244000
# Word                                   4.410714
#
# [115 rows x 1 columns]

# %%
d.tail()
# Out:
#                                          Rating
# Genres
# Video Players & Editors                4.063924
# Video Players & Editors;Creativity     4.100000
# Video Players & Editors;Music & Video  4.000000
# Weather                                4.244000
# Word                                   4.410714

# %%
df3.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#   Reviews Size  Installs  Type Price Content Rating  \
# 0     159  19M   10,000+  Free     0       Everyone
# 1     967  14M  500,000+  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up

# %%
pivot = pd.pivot_table(columns = 'Genres',
                      values = 'Rating',
                      data = df3, aggfunc = "mean")
pivot
# Out:
# Genres    Action  Action;Action & Adventure  Adventure  \
# Rating  4.285475                   4.311765   4.180822
#
# Genres  Adventure;Action & Adventure  Adventure;Brain Games  \
# Rating                      4.423077                    4.6
#
# Genres  Adventure;Education    Arcade  Arcade;Action & Adventure  \
# Rating                  4.1  4.304348                   4.346667
#
# Genres  Arcade;Pretend Play  Art & Design  ...     Tools  Tools;Education  \
# Rating                  4.5          4.38  ...  4.046585              4.5
#
# Genres  Travel & Local  Travel & Local;Action & Adventure    Trivia  \
# Rating        4.109333                                4.1  4.039286
#
# Genres  Video Players & Editors  Video Players & Editors;Creativity  \
# Rating                 4.063924                                 4.1
#
# Genres  Video Players & Editors;Music & Video  Weather      Word
# Rating                                    4.0    4.244  4.410714
#
# [1 rows x 115 columns]

# %%
pivot.transpose()
# Out:
#                                          Rating
# Genres
# Action                                 4.285475
# Action;Action & Adventure              4.311765
# Adventure                              4.180822
# Adventure;Action & Adventure           4.423077
# Adventure;Brain Games                  4.600000
# ...                                         ...
# Video Players & Editors                4.063924
# Video Players & Editors;Creativity     4.100000
# Video Players & Editors;Music & Video  4.000000
# Weather                                4.244000
# Word                                   4.410714
#
# [115 rows x 1 columns]
